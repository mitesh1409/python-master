# %%
import queries

print(dir(queries))
# Out:
# ['SQL_CHART_DATA_BY_SWIMMER_EVENT_SESSION', 'SQL_SESSIONS', 'SQL_SWIMMERS_BY_SESSION', 'SQL_SWIMMERS_EVENTS_BY_SESSION', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__']

# %%
statements = []

for item in dir(queries):
    if not item.startswith("__"):
        statements.append(item)

print(statements)
# Out:
# ['SQL_CHART_DATA_BY_SWIMMER_EVENT_SESSION', 'SQL_SESSIONS', 'SQL_SWIMMERS_BY_SESSION', 'SQL_SWIMMERS_EVENTS_BY_SESSION']

# %%
[item for item in dir(queries) if not item.startswith("__")]
# Out:
# ['SQL_CHART_DATA_BY_SWIMMER_EVENT_SESSION',
#  'SQL_SESSIONS',
#  'SQL_SWIMMERS_BY_SESSION',
#  'SQL_SWIMMERS_EVENTS_BY_SESSION']

# %%
import sqlite3

SWIMCLUB_DB = "swimclub.db"

print(queries.SQL_SESSIONS)
# Out:
#     select distinct created_at
#     from times

# %%
with sqlite3.connect(SWIMCLUB_DB) as dbc:
    db_cursor = dbc.cursor()
    sessions = db_cursor.execute(queries.SQL_SESSIONS).fetchall()

print(sessions)
# Out:
# [('2026-09-05 07:52:54',), ('2026-09-05 10:49:03',)]

# %%
print(queries.SQL_SWIMMERS_BY_SESSION)
# Out:
#     select distinct swimmers.name, swimmers.age
#     from swimmers, times
#     where times.swimmer_id = swimmers.id and
#     date(times.created_at) = ?
#     order by swimmers.name

# %%
with sqlite3.connect(SWIMCLUB_DB) as dbc:
    db_cursor = dbc.cursor()
    swimmers = db_cursor.execute(queries.SQL_SWIMMERS_BY_SESSION, ("2026-09-05",)).fetchall()

print(swimmers)
# Out:
# [('Abi', 10), ('Ali', 12), ('Alison', 14), ('Aurora', 13), ('Bill', 18), ('Blake', 15), ('Calvin', 9), ('Carl', 15), ('Chris', 17), ('Darius', 13), ('Darius', 8), ('Dave', 17), ('Elba', 14), ('Emma', 13), ('Erika', 15), ('Hannah', 13), ('Katie', 9), ('Lizzie', 14), ('Maria', 9), ('Mike', 15), ('Owen', 15), ('Ruth', 13), ('Tasmin', 15)]

# %%
print(queries.SQL_SWIMMERS_EVENTS_BY_SESSION)
# Out:
#     select distinct events.distance, events.stroke
#     from swimmers, events, times
#     where times.swimmer_id = swimmers.id and
#     times.event_id = events.id and
#     (swimmers.name = ? and swimmers.age = ?) and
#     date(times.created_at) = ?

# %%
with sqlite3.connect(SWIMCLUB_DB) as dbc:
    db_cursor = dbc.cursor()
    events = db_cursor.execute(queries.SQL_SWIMMERS_EVENTS_BY_SESSION, ("Darius", 13, "2026-09-05")).fetchall()

print(events)
# Out:
# [('100m', 'Back'), ('100m', 'Breast'), ('100m', 'Fly'), ('200m', 'IM')]

# %%
with sqlite3.connect(SWIMCLUB_DB) as dbc:
    db_cursor = dbc.cursor()
    events = db_cursor.execute(queries.SQL_SWIMMERS_EVENTS_BY_SESSION, ("Darius", 8, "2026-09-05")).fetchall()

print(events)
# Out:
# [('50m', 'Back'), ('50m', 'Free'), ('50m', 'Breast')]

# %%
print(queries.SQL_CHART_DATA_BY_SWIMMER_EVENT_SESSION)
# Out:
#     select times.time
#     from swimmers, events, times
#     where times.swimmer_id = swimmers.id and
#     times.event_id = events.id and
#     (swimmers.name = ? and swimmers.age = ?) and
#     (events.distance = ? and events.stroke = ?) and
#     date(times.created_at) = ?

# %%
with sqlite3.connect(SWIMCLUB_DB) as dbc:
    db_cursor = dbc.cursor()
    times = db_cursor.execute(queries.SQL_CHART_DATA_BY_SWIMMER_EVENT_SESSION, ("Darius", 13, "100m", "Fly", "2026-09-05")).fetchall()

print(times)
# Out:
# [('1:27.95',), ('1:21.07',), ('1:30.96',), ('1:23.22',), ('1:27.95',), ('1:28.30',), ('1:23.22',), ('1:21.07',), ('1:27.95',), ('1:27.95',), ('1:28.30',), ('1:30.96',)] 12

# %%
import data_access

print([item for item in dir(data_access) if not item.startswith("__")])
# Out:
# ['SWIMCLUB_DB', 'get_swim_sessions', 'get_swimmers_by_session', 'get_swimmers_events_by_session', 'get_swimmers_times_by_event_and_session', 'queries', 'sqlite3']

# %%
data = data_access.get_swim_sessions()

# for value in data:
#     print(value[0].split(" ")[0])

[value[0].split(" ")[0] for value in data]
# Out:
# ['2026-09-05', '2026-09-05']

# %%
data = data_access.get_swimmers_by_session("2026-09-05")
# print(f"{data[0][0]}-{data[0][1]}")

[f"{value[0]}-{value[1]}" for value in data]
# Out:
# ['Abi-10',
#  'Ali-12',
#  'Alison-14',
#  'Aurora-13',
#  'Bill-18',
#  'Blake-15',
#  'Calvin-9',
#  'Carl-15',
#  'Chris-17',
#  'Darius-13',
#  'Darius-8',
#  'Dave-17',
#  'Elba-14',
#  'Emma-13',
#  'Erika-15',
#  'Hannah-13',
#  'Katie-9',
#  'Lizzie-14',
#  'Maria-9',
#  'Mike-15',
#  'Owen-15',
#  'Ruth-13',
#  'Tasmin-15']

# %%
data = data_access.get_swimmers_events_by_session("Darius", 8, "2026-09-05")
# print(data)
[f"{value[0]} {value[1]}" for value in data]
# Out:
# ['50m Back', '50m Free', '50m Breast']

# %%
data = data_access.get_swimmers_times_by_event_and_session("Darius", 8, "50m", "Free", "2026-09-05")
# print(data)
[value[0] for value in data]
# Out:
# ['39.42', '36.13', '37.66', '39.07']

# %%
numbers = [10, 20, 30, 40, 50]

def double(value):
    return value * 2

doubles = map(double, numbers)

print(list(doubles))
# Out:
# [20, 40, 60, 80, 100]

# %%
import swimclub

times = ['1:20', '1:25', '1:30']

time_values = [swimclub._time_to_hundredths_seconds(time) for time in times]
print(time_values)
# Out:
# [8000, 8500, 9000]
